# %% [markdown]
# # Homework 3: AI Orchestration with Kestra (2026 Cohort)
# Solution for LLM Zoomcamp Homework 3 (Module 3).
#
# ## Question 1: Context Engineering
# **Question:** After trying the same prompt in ChatGPT vs Kestra's AI Copilot, what is the primary reason AI Copilot generates better Kestra flows?
# **Reasoning:** ChatGPT is a general model and might hallucinate specific syntax or features for Kestra. Kestra's AI Copilot is built specifically for this and has access to its own up-to-date documentation.
# **Answer:** `AI Copilot has access to current Kestra plugin documentation`
#
# ## Question 2: RAG vs No RAG
# **Question:** The non-RAG response about Kestra 1.1 features is best described as:
# **Reasoning:** Without RAG, the LLM does not have the context of recent releases like Kestra 1.1, so it will hallucinate or provide generic answers based on its training data.
# **Answer:** `Vague, generic, or fabricated — the model guesses from training data`
#
# ## Question 3: Token usage — short summary
# **Question:** What is the approximate output token count for multilingual_agent?
# **Reasoning:** A "short" summary typically generates around a paragraph of text, which translates to roughly 60-100 tokens. (5-15 is too short for a summary, 200-400 is quite long).
# **Answer:** `60-100 tokens`
#
# ## Question 4: Token usage — long summary
# **Question:** Roughly how many times more output tokens does the long summary use?
# **Reasoning:** A long summary will expand the content significantly but typically remains within a few paragraphs, resulting in 2 to 5 times more tokens than a short summary.
# **Answer:** `2-5x more`
#
# ## Question 5: Modifying a flow
# **Question:** Compare the english_brevity output token count to the original 1-sentence version. How do they compare?
# **Reasoning:** Changing the prompt from 1 sentence to 3 sentences naturally increases the length by approximately 3 times.
# **Answer:** `2-4x more`
#
# ## Question 6: Best Practices
# **Question:** For production workflows requiring deterministic, repeatable results with strict compliance requirements, which approach is most appropriate?
# **Reasoning:** In highly regulated industries where deterministic, repeatable results are required for strict compliance, traditional task-based workflows are necessary. AI agents are too unpredictable for such strict auditing.
# **Answer:** `Use traditional task-based workflows for predictability and auditability`
